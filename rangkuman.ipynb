# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
awal = pd.read_excel('final.xlsx')

# %%
awal
# Out:
#    Tanggal  Tn  Tx  Tavg
# 0     2011  24  31    27
# 1     2012  24  32    27
# 2     2013  24  31    27
# 3     2014  24  32    28
# 4     2021  28  32    28

# %%
plt.figure(figsize=(10,10))
plt.title('suhu semarang 10 tehun terakhr')
plt.plot(awal['Tanggal'],awal['Tn'],label='smin')
plt.plot(awal['Tanggal'],awal['Tx'],label='smax')
plt.plot(awal['Tanggal'],awal['Tavg'],label='tavg')

plt.legend()
plt.show()

# %%
awal.plot(x="Tanggal", y="Tavg", kind="scatter")
awal.plot(x="Tanggal", y="Tn", kind="scatter")
awal.plot(x="Tanggal", y="Tx", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Tanggal', ylabel='Tx'>

# %%
def rav (x):
    return x.rolling(window=5).mean()

rav=np.mean(awal['Tavg']),np.mean(awal['Tn']),np.mean(awal['Tx'])

# %%
rav
# Out:
# (28.14372990353698, 25.02710280373832, 32.24376996805112)
